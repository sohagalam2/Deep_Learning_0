# %% [markdown]
# <a href="https://colab.research.google.com/github/sohagalam2/Deep_Learning_0/blob/main/ML_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
print("Size = ", len(speed))
import numpy
from scipy import stats
print("mean = ", numpy.mean(speed))
print("Median = ", numpy.median(speed))
print("Mode = ", stats.mode(speed))
print("Standard deviation = ", numpy.std(speed))
print("Variance = ", numpy.var(speed))

# %%
import numpy as np
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
print("75% percentile = ", np.percentile(ages, 75))

# %%
import numpy as np
data_set = np.random.uniform(0.0, 5.0, 100000)
print("Standard Deviation = ", np.std(data_set))
print("Variance = ", np.var(data_set))
import matplotlib.pyplot as plt
plt.hist(data_set, 10) # value should be 5 as we have selected value between zero to 5 and 250 values will be found
plt.show()

# %% [markdown]
# Normal Curve using random funciton

# %%
import matplotlib.pyplot as plt
plt.hist(np.random.normal(5.0, 1.0, 100000), 100) # here mean is 5 and 1 is standard deviation
plt.show()

# %% [markdown]
# ***Linear Regression***

# %%
import matplotlib.pyplot as plt
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
from scipy import stats
slope, intercept, r_value, p_value, std_error = stats.linregress(x,y)
def myfunc(x):
  return slope*x + intercept
mymodel = list(map(myfunc, x))
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show()
print(r_value,p_value)
speed = myfunc(10)
print("Car speed = ", speed)

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]
slope, intercept, r, p, std_err = stats.linregress(x,y)
def myfunc(x):
  return slope*x + intercept

mymodel = list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()
print("R_value = ", r)

# %% [markdown]
# Polynomial **Regression**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
mymodel = np.poly1d(np.polyfit(x,y,3)) # Here, 3 represents degree of polynomial.
                                       # we have to use wisely how to fit data in  the model
# myline = np.linspace(1,22,100) #np.linespace(start, stop, num) , num = how many values to be considered to draw curve and we will be used in the polynomial function to find y axis value.

# plt.scatter(x,y)
# plt.plot(myline,mymodel(myline))
# plt.show()

#Finding R squared value
from sklearn.metrics import r2_score
print("R squared value = ", r2_score(y, mymodel(x)))

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics  import r2_score
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]
mymodel = np.poly1d(np.polyfit(x,y, 3))
myline = np.linspace(2,95, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
print("R squared value = ", r2_score(y, mymodel(x)))
